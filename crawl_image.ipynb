# %% [markdown]
# <a href="https://colab.research.google.com/github/io1007/MyGit/blob/master/crawl_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install icrawler

# %%
# !pwd
from icrawler.builtin import BingImageCrawler

import sys
import os

save_path = './learning/images/nagase'
keyword = '長瀬智也'

if not os.path.exists(save_path):
  os.makedirs(save_path)

crawler = BingImageCrawler(storage = {'root_dir':save_path})
crawler.crawl(keyword = keyword,max_num = 300)
# Out:
# /content
# 2020-11-06 10:45:45,076 - INFO - icrawler.crawler - start crawling...
# 2020-11-06 10:45:45,078 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-11-06 10:45:45,082 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-11-06 10:45:45,085 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-11-06 10:45:45,434 - INFO - parser - parsing result page https://www.bing.com/images/async?q=長瀬智也&first=0
# 2020-11-06 10:45:45,612 - INFO - downloader - image #1	https://i1.wp.com/erimakee.com/wp-content/uploads/2020/02/AMIfv96JJD_tAPeqc3D_uDP2X0nbskJks1ai7KVUGWrj6TQN2iESTDZf1Y7Nbz2PhkiUeSB5ohZ3H-FsjihN3ZTpmdevH8t_q4xz_qZPoLxSeSjVm2vsbcMk5FzMOMuC066A5didi3P6zSpfdzNEUSqBfp65D0xFLjIkZMoIkMKhJBhuDuAUjmc.jpg
# 2020-11-06 10:45:46,923 - INFO - downloader - image #2	https://rank1-media.com/file/parts/I0000788/38dd46114c515955388505000ff9b116.jpg
# ...
